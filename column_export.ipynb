# %% [markdown]
# This file pulls the columns headers from the ML model to be loaded into the websites dataframe

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from pycaret.nlp import *
from pycaret.classification import *

from sklearn.feature_extraction.text import CountVectorizer

# %%
model = load_model('deployment')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
text = model.steps[0][1]
print(text)
# Out:
# DataTypes_Auto_infer(display_types=False, ml_usecase='classification',
#                      numerical_features=['10', 'able', 'about', 'absolutely',
#                                          'across', 'action', 'actually', 'add',
#                                          'added', 'admit', 'adult', 'adventure',
#                                          'after', 'again', 'against', 'age',
#                                          'ago', 'all', 'almost', 'alone',
#                                          'along', 'alpha', 'already', 'also',
#                                          'although', 'always', 'am', 'amazing',
#                                          'amazon', 'american', ...],
#                      target='derived_ratings')

# %%
text.numerical_features
# Out:
# ['10',
#  'able',
#  'about',
#  'absolutely',
#  'across',
#  'action',
#  'actually',
#  'add',
#  'added',
#  'admit',
#  'adult',
#  'adventure',
#  'after',
#  'again',
#  'against',
#  'age',
#  'ago',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'alpha',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'amazing',
#  'amazon',
#  'american',
#  'an',
#  'and',
#  'annoying',
#  'another',
#  'any',
#  'anyone',
#  'anything',
#  'are',
#  'aren',
#  'around',
#  'as',
#  'at',
#  'attention',
#  'attraction',
#  'author',
#  'authors',
#  'away',
#  'awesome',
#  'back',
#  'background',
#  'bad',
#  'based',
#  'basically',
#  'be',
#  'beautiful',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'been',
#  'before',
#  'beginning',
#  'begins',
#  'behind',
#  'being',
#  'believable',
#  'believe',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'big',
#  'bit',
#  'body',
#  'book',
#  'books',
#  'boring',
#  'both',
#  'bought',
#  'boy',
#  'boyfriend',
#  'break',
#  'bring',
#  'brother',
#  'brothers',
#  'brought',
#  'building',
#  'business',
#  'but',
#  'buy',
#  'by',
#  'call',
#  'called',
#  'came',
#  'can',
#  'cannot',
#  'cant',
#  'care',
#  'case',
#  'certain',
#  'certainly',
#  'chance',
#  'change',
#  'chapter',
#  'chapters',
#  'character',
#  'characters',
#  'check',
#  'chemistry',
#  'child',
#  'children',
#  'christian',
#  'city',
#  'class',
#  'clean',
#  'clear',
#  'cliffhanger',
#  'close',
#  'college',
#  'come',
#  'comes',
#  'coming',
#  'complete',
#  'completely',
#  'complex',
#  'connection',
#  'content',
#  'continue',
#  'control',
#  'could',
#  'couldn',
#  'couple',
#  'course',
#  'cover',
#  'crazy',
#  'cute',
#  'dark',
#  'daughter',
#  'day',
#  'days',
#  'dead',
#  'deal',
#  'death',
#  'decided',
#  'deep',
#  'definitely',
#  'depth',
#  'description',
#  'descriptions',
#  'despite',
#  'detail',
#  'details',
#  'developed',
#  'development',
#  'dialogue',
#  'did',
#  'didn',
#  'died',
#  'diet',
#  'different',
#  'difficult',
#  'disappointed',
#  'do',
#  'does',
#  'doesn',
#  'doesnt',
#  'doing',
#  'don',
#  'done',
#  'down',
#  'drama',
#  'drawn',
#  'due',
#  'duke',
#  'during',
#  'each',
#  'early',
#  'easily',
#  'easy',
#  'editing',
#  'either',
#  'else',
#  'emotional',
#  'emotions',
#  'end',
#  'ended',
#  'ending',
#  'ends',
#  'enjoy',
#  'enjoyable',
#  'enjoyed',
#  'enough',
#  'entertaining',
#  'entire',
#  'errors',
#  'especially',
#  'etc',
#  'even',
#  'events',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'evil',
#  'ex',
#  'exactly',
#  'example',
#  'excellent',
#  'except',
#  'exchange',
#  'exciting',
#  'expect',
#  'expected',
#  'experience',
#  'extremely',
#  'eyes',
#  'face',
#  'fact',
#  'fall',
#  'family',
#  'fan',
#  'fantastic',
#  'fantasy',
#  'far',
#  'fast',
#  'father',
#  'favorite',
#  'feel',
#  'feeling',
#  'feelings',
#  'feels',
#  'fell',
#  'felt',
#  'female',
#  'few',
#  'fiction',
#  'fight',
#  'figure',
#  'filled',
#  'finally',
#  'find',
#  'finding',
#  'finds',
#  'fine',
#  'finish',
#  'finished',
#  'first',
#  'five',
#  'follow',
#  'food',
#  'for',
#  'forced',
#  'forward',
#  'found',
#  'four',
#  'free',
#  'friend',
#  'friends',
#  'from',
#  'full',
#  'fun',
#  'funny',
#  'further',
#  'future',
#  'gave',
#  'genre',
#  'get',
#  'gets',
#  'getting',
#  'girl',
#  'girls',
#  'give',
#  'given',
#  'gives',
#  'giving',
#  'glad',
#  'go',
#  'god',
#  'goes',
#  'going',
#  'good',
#  'got',
#  'grammar',
#  'great',
#  'group',
#  'guess',
#  'guy',
#  'guys',
#  'had',
#  'half',
#  'hand',
#  'happen',
#  'happened',
#  'happens',
#  'happy',
#  'hard',
#  'has',
#  'hate',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'hea',
#  'head',
#  'heart',
#  'help',
#  'her',
#  'here',
#  'hero',
#  'heroine',
#  'herself',
#  'high',
#  'highly',
#  'him',
#  'himself',
#  'his',
#  'historical',
#  'history',
#  'home',
#  'honest',
#  'honestly',
#  'hope',
#  'hoping',
#  'hot',
#  'hours',
#  'house',
#  'how',
#  'however',
#  'huge',
#  'human',
#  'humor',
#  'hurt',
#  'husband',
#  'idea',
#  'if',
#  'im',
#  'immediately',
#  'important',
#  'in',
#  'including',
#  'information',
#  'instead',
#  'interest',
#  'interested',
#  'interesting',
#  'into',
#  'intriguing',
#  'involved',
#  'is',
#  'isn',
#  'issue',
#  'issues',
#  'it',
#  'its',
#  'itself',
#  'jackson',
#  'jane',
#  'job',
#  'journey',
#  'just',
#  'kate',
#  'keep',
#  'keeps',
#  'kept',
#  'kids',
#  'kind',
#  'kindle',
#  'king',
#  'knew',
#  'know',
#  'knowing',
#  'known',
#  'knows',
#  'lady',
#  'language',
#  'last',
#  'later',
#  'laugh',
#  'lead',
#  'learn',
#  'least',
#  'leave',
#  'leaves',
#  'leaving',
#  'left',
#  'less',
#  'let',
#  'level',
#  'life',
#  'light',
#  'like',
#  'liked',
#  'line',
#  'link',
#  'list',
#  'little',
#  'live',
#  'lives',
#  'living',
#  'll',
#  'long',
#  'longer',
#  'look',
#  'looking',
#  'lose',
#  'lost',
#  'lot',
#  'lots',
#  'love',
#  'loved',
#  'loves',
#  'loving',
#  'made',
#  'magic',
#  'main',
#  'major',
#  'make',
#  'makes',
#  'making',
#  'male',
#  'man',
#  'many',
#  'marriage',
#  'married',
#  'marry',
#  'matter',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'means',
#  'meet',
#  'meets',
#  'men',
#  'met',
#  'mia',
#  'middle',
#  'might',
#  'mind',
#  'missing',
#  'modern',
#  'mom',
#  'moment',
#  'moments',
#  'money',
#  'more',
#  'most',
#  'mostly',
#  'mother',
#  'move',
#  'moving',
#  'mr',
#  'ms',
#  'much',
#  'murder',
#  'must',
#  'my',
#  'myself',
#  'mysteries',
#  'mystery',
#  'name',
#  'need',
#  'needed',
#  'needs',
#  'never',
#  'new',
#  'next',
#  'nice',
#  'night',
#  'no',
#  'nor',
#  'normal',
#  'not',
#  'nothing',
#  'novel',
#  'novella',
#  'novels',
#  'now',
#  'number',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'older',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'opinion',
#  'or',
#  'order',
#  'other',
#  'others',
#  'our',
#  'out',
#  'over',
#  'overall',
#  'own',
#  'paced',
#  'page',
#  'pages',
#  'parents',
#  'part',
#  'parts',
#  'past',
#  'people',
#  'perfect',
#  'perhaps',
#  'period',
#  'person',
#  'personal',
#  'pick',
#  'place',
#  'plan',
#  'play',
#  'please',
#  'plot',
#  'plus',
#  'point',
#  'police',
#  'poor',
#  'possible',
#  'potential',
#  'power',
#  'predictable',
#  'premise',
#  'pretty',
#  'previous',
#  'price',
#  'probably',
#  'problem',
#  'problems',
#  'product',
#  'put',
#  'putting',
#  'questions',
#  'quick',
#  'quickly',
#  'quite',
#  'rather',
#  'rating',
#  're',
#  'read',
#  'reader',
#  'readers',
#  'reading',
#  'reads',
#  'ready',
#  'real',
#  'realistic',
#  'realize',
#  'really',
#  'reason',
#  'reasons',
#  'received',
#  'recipes',
#  'recommend',
#  'recommended',
#  'relationship',
#  'relationships',
#  'rest',
#  'review',
#  'reviews',
#  'rich',
#  'right',
#  'romance',
#  'romantic',
#  'run',
#  'sad',
#  'said',
#  'sam',
#  'same',
#  'save',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'scene',
#  'scenes',
#  'school',
#  'second',
#  'secret',
#  'secrets',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seems',
#  'seen',
#  'sees',
#  'self',
#  'sense',
#  'series',
#  'seriously',
#  'set',
#  'setting',
#  'several',
#  'sex',
#  'sexual',
#  'sexy',
#  'she',
#  'short',
#  'should',
#  'show',
#  'shows',
#  'side',
#  'simple',
#  'simply',
#  'since',
#  'single',
#  'sister',
#  'situation',
#  'situations',
#  'slow',
#  'small',
#  'smart',
#  'so',
#  'some',
#  'someone',
#  'something',
#  'sometimes',
#  'somewhat',
#  'son',
#  'soon',
#  'sorry',
#  'sort',
#  'special',
#  'spent',
#  'stand',
#  'star',
#  'stars',
#  'start',
#  'started',
#  'starts',
#  'stay',
#  'steamy',
#  'still',
#  'stop',
#  'stories',
#  'story',
#  'storyline',
#  'strong',
#  'stuff',
#  'stupid',
#  'style',
#  'such',
#  'super',
#  'supposed',
#  'sure',
#  'surprise',
#  'surprised',
#  'suspense',
#  'sweet',
#  'take',
#  'taken',
#  'takes',
#  'taking',
#  'tale',
#  'talk',
#  'talking',
#  'tell',
#  'telling',
#  'tells',
#  'than',
#  'thank',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'thing',
#  'things',
#  'think',
#  'thinking',
#  'thinks',
#  'third',
#  'this',
#  'thoroughly',
#  'those',
#  'though',
#  'thought',
#  'thoughts',
#  'three',
#  'through',
#  'throughout',
#  'time',
#  'times',
#  'title',
#  'to',
#  'today',
#  'together',
#  'told',
#  'too',
#  'took',
#  'top',
#  'totally',
#  'town',
#  'tried',
#  'tries',
#  'trilogy',
#  'trouble',
#  'true',
#  'truly',
#  'trust',
#  'truth',
#  'try',
#  'trying',
#  'turn',
#  'turned',
#  'turns',
#  'twist',
#  'twists',
#  'two',
#  'type',
#  'under',
#  'understand',
#  'unfortunately',
#  'unique',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'using',
#  'usually',
#  've',
#  'very',
#  'view',
#  'violence',
#  'wait',
#  'want',
#  'wanted',
#  'wanting',
#  'wants',
#  'war',
#  'was',
#  'wasn',
#  'waste',
#  'way',
#  'ways',
#  'we',
#  'wedding',
#  'weight',
#  'well',
#  'went',
#  'were',
#  'what',
#  'when',
#  'where',
#  'whether',
#  'which',
#  'while',
#  'who',
#  'whole',
#  'why',
#  'wife',
#  'will',
#  'wish',
#  'with',
#  'within',
#  'without',
#  'woman',
#  'women',
#  'won',
#  'wonderful',
#  'word',
#  'words',
#  'work',
#  'worked',
#  'working',
#  'works',
#  'world',
#  'worth',
#  'would',
#  'wouldn',
#  'wow',
#  'write',
#  'writer',
#  'writes',
#  'writing',
#  'written',
#  'wrong',
#  'year',
#  'years',
#  'yes',
#  'yet',
#  'you',
#  'young',
#  'younger',
#  'your',
#  'yourself']
