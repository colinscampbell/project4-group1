# %% [markdown]
# #Colin's File for NLP Testing

# %%
from pycaret.nlp import *
import pandas as pd

# %%
df = pd.read_csv("Kindle_Reviews.csv")

# %%
test = df.head(10000)
test
# Out:
#       Unnamed: 0  overall  verified      reviewerID        asin  \
# 0              0        5      True   A8WQ7MAG3HFOZ  B000FA5KK0
# 1              1        5      True   A1E0MODSRYP7O  B000FA5KK0
# 2              2        5      True    AFVJCR70132Z  B000FBFMHU
# 3              3        5      True  A35TPI5B6O08A0  B000FBFMHU
# 4              4        5      True  A25VQSS06RDWMJ  B000FBFMHU
# ...          ...      ...       ...             ...         ...
# 9995        9995        5      True   A73IK4VT0XZS6  B007J4A4KQ
# 9996        9996        5      True  A3RR6TXW4UX0D2  B007J4A4KQ
# 9997        9997        5      True  A1S3CIZFVRRJKE  B007J4A4KQ
# 9998        9998        5      True  A22Y9ZFFA6RG4E  B007J4A4KQ
# 9999        9999        5      True  A2NJ4R9TXYDJ27  B007J4A4KQ
#
#                                              reviewText  \
# 0                          Love Max, always a fun twist
# 1                         As usual for him, a good book
# ...

# %%
nlp_experiment = setup(data = test, target = 'reviewText', session_id = 123)
#note: takes ~50 seconds to run 10,000 rows on my machine
# Out:
# <style type="text/css">
# </style>
# <table id="T_3aa09">
#   <thead>
#     <tr>
#       <th id="T_3aa09_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3aa09_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3aa09_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3aa09_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <td id="T_3aa09_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_3aa09_row1_col1" class="data row1 col1" >10000</td>
#     </tr>
#     <tr>
#       <td id="T_3aa09_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_3aa09_row2_col1" class="data row2 col1" >11517</td>
#     </tr>
#     <tr>
#       <td id="T_3aa09_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_3aa09_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>
